# %% [markdown]
# ### Skalowanie & Kodowanie & Strojenie hiperparametrów modeli

# %%
# Pakiety
import pandas as pd 
import numpy as np

import category_encoders as ce
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, train_test_split, RandomizedSearchCV
from datetime import datetime
import matplotlib.pyplot as plt

from sklearn import preprocessing 
from sklearn.preprocessing import StandardScaler

from sklearn import metrics
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.metrics import precision_score

np.random.seed(123) 

# Wczytywanie danych
#data = pd.read_csv('/home/elzbieta/WUM_project1/Feature_Engineering/german_credit_data_dataset.csv')
data = pd.read_csv('german_credit_data_dataset.csv')
data = pd.DataFrame(data)

# %%
# Kolumny z danymi numerycznymi
num = data.select_dtypes(include=['float64', 'int']).drop('customer_type', axis = 1).columns

# Kolumny z danymi kategorycznymi
cat = data.select_dtypes(include=['object']).columns.tolist()

# %% [markdown]
# ### 1. Skalowanie danych numerycznych

# %%
scaler = StandardScaler()
scaled = data.copy()
scaled[num] = scaler.fit_transform(data[num])

# %% [markdown]
# ### 2. Podział na zbiory trenigowe i testowe

# %%
X_train, X_test, Y_train, Y_test = train_test_split(data.drop('customer_type', axis=1), data['customer_type'])
scaled_X_train, scaled_X_test, scaled_Y_train, scaled_Y_test = train_test_split(scaled.drop('customer_type', axis=1), scaled['customer_type'])

# %% [markdown]
# ### 3. Encoding

# %% [markdown]
# #### 3.1. One-Hot Encoding

# %%
ohe = ce.OneHotEncoder(data, cols = cat)

# Ramka zakodowana nieskalowana
ohe_train = ohe.fit_transform(X = X_train, y = Y_train)
ohe_test = ohe.transform(X_test)

# Ramka zakodowana, przeskalowana
ohe_scaled_train = ohe.fit_transform(X = scaled_X_train, y = scaled_Y_train)
ohe_scaled_test = ohe.transform(scaled_X_test)

df = pd.DataFrame(ohe_train, Y_train)
#df.to_csv('/home/elzbieta/WUM_project1/Final/dane.csv', index = False)

# %% [markdown]
# #### 3.2. Target Encoding

# %%
te = ce.TargetEncoder(cols = cat)

# Ramka zakodowana nieskalowana
te_train = te.fit_transform(X = X_train, y = Y_train)
te_test = te.transform(X_test)

# Ramka zakodowana, przeskalowana
te_scaled_train = te.fit_transform(X = scaled_X_train, y = scaled_Y_train)
te_scaled_test = te.transform(scaled_X_test)

# %% [markdown]
# #### 3.3. James Stein Encoding

# %%
js = ce.JamesSteinEncoder(cols = cat)

# Ramka zakodowana nieskalowana
js_train = js.fit_transform(X = X_train, y = Y_train)
js_test = js.transform(X_test)

# Ramka zakodowana, przeskalowana
js_scaled_train = js.fit_transform(X = scaled_X_train, y = scaled_Y_train)
js_scaled_test = js.transform(scaled_X_test)

# %% [markdown]
# #### 3.4. Polynomial Encoding

# %%
pe = ce.PolynomialEncoder(cols = cat)

# Ramka zakodowana nieskalowana
pe_train = pe.fit_transform(X = X_train, y = Y_train)
pe_test = pe.transform(X_test)

# Ramka zakodowana, przeskalowana
pe_scaled_train = pe.fit_transform(X = scaled_X_train, y = scaled_Y_train)
pe_scaled_test = pe.transform(scaled_X_test)

# %% [markdown]
# ### 4. Model

# %% [markdown]
# #### 4.1. Random Forest
# Hiperparametry:
#
# **n_estimators** - ilość drzew składowych (int, domyślnie 100)
# **criterion** - funkcja miary jakości podziału (string, domyślnie gini)
# **max_depth** - maksymalna głębokość drzewa (int, domyślnie None)
# **min_samples_split** - minimalna liczba obserwacji wymagana do podziału węzła wewnętrznego (int/float, domyślnie 2)
# **min_samples_leaf** - minimalna liczba obserwacji wymagana względem liścia (int, domyślnie 1)
# **min_weight_fraction_leaf** - minimalna frakcja wag wymagana względem liścia (domyślnie 0)
# **max_features** - ilość cech branych pod uwagę podczas poszukiwania najlepszego podziału (string). Jeśli “sqrt”, to max_features=sqrt(n_features), jeśli “log2”, to max_features=log2(n_features).
# **max_leaf_nodes** - maksymalna liczba liści (int, domyślnie None)
# **min_impurity_decrease** - węzeł zostanie podzielony, jeśli podział ten spowoduje zmniejszenie miary impurity większe lub równe tej wartości. (float, domyślnie 0)
# **min_impurity_split** - Próg zatrzymania wzrostu drzew. Węzeł rozdzieli się, jeśli jego impurity przekroczy próg, w przeciwnym razie będzie liściem. (float, default 1e-7)
# **bootstrap** - stosowanie bootstrap (bool, domyślnie True)
# **oob_score** - Gdy zestaw treningowy dla bieżącego drzewa jest rysowany przez próbkowanie z wymianą, około jedna trzecia przypadków jest pomijana. Te dane OOB są używane do uzyskania bezstronnego oszacowania błędu klasyfikacji (bool, domyślnie False)
# **oob_score** - liczba powtórzeń instukcji fit, predict, ect.
# **random_state** - kontroluje losowość procedury bootstrap
# **verbose** - int, domyślnie 0 - im wyższa liczba tym więcej informacji uzyskami na temat procedur fit i predict
# **warm_start** - Po ustawieniu wartości True ponownie użyje bieżącego rozwiązania, aby dopasować i dodać więcej estymatorów do zestawu, w przeciwnym razie po prostu zmieni cały nowy las. (bool, domyślnie False)
# **ccp_alpha** - dotyczy przycinania, zostanie wybrane poddrzewo o największym koszcie, który jest mniejszy niż ccp_alpha. Domyślnie 0.0, czyli przycinanie nie jest wykonywane.
# **max_samples** - dotyczy procedury bootstrap (domyślnie None)

# %%
# Model
rf_classifier = RandomForestClassifier()

# Hiperparametry
param_grid = {
    'n_estimators' : [50, 100, 200],
    'max_depth' : [None, 4, 8],
    'min_samples_split' : [1.0, 2, 4],
    'min_samples_leaf' : [1, 2, 3],
    'min_weight_fraction_leaf' : [0, 0.2, 0.5],
    'max_features' : ['sqrt', 'log2'],
    'max_leaf_nodes' : [None, 4, 10],
    'min_impurity_decrease' : [1e-7, 1e-5, 1e-3],
    'bootstrap' : [True, False],
    'oob_score' : [True, False],
    'n_jobs' : [None, 2, 4],
    'random_state' : [None, 42],
    'warm_start' : [True, False],
    'ccp_alpha' : [0.0, 0.1, 0.2],
    'max_samples' : [None, 0.1, 0.5, 0.9]    
}

# %%
# Strojenie modelu dla kodowania One Hot.
rf_grid_search = GridSearchCV(rf_classifier, param_grid = param_grid, cv = 5)
rf_grid_search.fit(ohe_train, Y_train)
model1 = rf_grid_search.best_estimator_

# %%
# Z tymn może być problem, mój komputer nie daje rady a strojenie tych parametrów oddzielnie wg mnie nie ma sensu
# Przydałoby się jeszcze zastanowić czy są takie kolumny, z których można by zrezygnować w czasie modelowania

# %% [markdown]
# #### 4.2. XGBoost
#
# Hiperparametry:
#
# -**n_estimators** - ilość drzew składowych (int, domyślnie 100)
#
# -**max_depth** - do uzpełnienia
#
# -**min_child_weight** - do uzpełnienia
#
# -**gamma** - do uzpełnieni
#
# -**subsample** - do uzpełnieni
#
# -**colsample_bytree** - do uzpełnieni
#
# -**learning_rate** - do uzpełnieni

# %%
# Funkcja, która znajduje optymalną ilosć drzew (n_estimators parameter) uzywając funkcji cv xgboosta dla
# danej wartosci learning_rate i zmienia wartosc n_parametres odpowiednio

def modelfit(alg, dtrain, predictors, cv_folds = 5, early_stopping_rounds = 50):
    xgb_param = alg.get_xgb_params()
    xgtrain = xgb.DMatrix(dtrain[predictors].values, label=dtrain[target].values)
    cvresult = xgb.cv(xgb_param, xgtrain, num_boost_round = alg.get_params()['n_estimators'],
                      nfold=cv_folds, metrics='auc', early_stopping_rounds = early_stopping_rounds)
    alg.set_params(n_estimators = cvresult.shape[0])
    
    
# Funkcja, która zmierzy nam ilsoc czasu potrzebna na wykonanie danej funkcji

def timer(start_time=None):from datetime import datetime
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
param_grid = {
    'max_depth': range (2, 10, 1),
    'min_child_weight': range(1,10,1),
    'gamma': [i/10.0 for i in range(0,50,5)],
    'subsample': [i/100.0 for i in range(50,100,5)],
    'colsample_bytree': [i/100.0 for i in range(50,100,5)],
    'learning_rate': [0.001,0.01,0.1]
    }

xgb_classifier = xgb.XGBClassifier(learning_rate=0.02, n_estimators=600, objective='binary:logistic',
                    silent=True, nthread=4)

# %%
random_search = RandomizedSearchCV(xgb_classifier, param_distributions = param_grid, n_iter = 1000,
                                   scoring = 'roc_auc', n_jobs = 1, cv = 5, verbose = 3, random_state = 1001 )

# Here we go
start_time = timer(None) # aktualna godzina
random_search.fit(ohe_train, Y_train)
timer(start_time) # ile czasu minelo od start_time
random_search.best_estimator_
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits
# [CV] subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65
# [CV]  subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65, score=0.798, total=   0.1s
# [CV] subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65, score=0.744, total=   0.1s
# [CV] subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65
# [CV]  subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65, score=0.789, total=   0.1s
# [CV] subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [CV]  subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65, score=0.728, total=   0.2s
# [CV] subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65
# [CV]  subsample=0.95, min_child_weight=2, max_depth=3, learning_rate=0.01, gamma=3.5, colsample_bytree=0.65, score=0.749, total=   0.1s
# [CV] subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6
# [CV]  subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6, score=0.799, total=   0.2s
# [CV] subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6
# [CV]  subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6, score=0.722, total=   0.2s
# [CV] subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6
# [CV]  subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6, score=0.788, total=   0.2s
# [CV] subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6
# [CV]  subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6, score=0.694, total=   0.2s
# [CV] subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6
# [CV]  subsample=0.75, min_child_weight=9, max_depth=4, learning_rate=0.001, gamma=2.0, colsample_bytree=0.6, score=0.699, total=   0.2s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.755, total=   0.4s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.734, total=   0.4s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.774, total=   0.4s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.679, total=   0.4s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.694, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75
# [CV]  subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75, score=0.798, total=   0.3s
# [CV] subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75
# [CV]  subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75, score=0.734, total=   0.3s
# [CV] subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75
# [CV]  subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75, score=0.791, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75
# [CV]  subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75, score=0.704, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75
# [CV]  subsample=0.7, min_child_weight=5, max_depth=7, learning_rate=0.001, gamma=1.5, colsample_bytree=0.75, score=0.700, total=   0.4s
# [CV] subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65, score=0.797, total=   0.2s
# [CV] subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65, score=0.727, total=   0.2s
# [CV] subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65, score=0.788, total=   0.2s
# [CV] subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65, score=0.701, total=   0.2s
# [CV] subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.9, min_child_weight=6, max_depth=4, learning_rate=0.001, gamma=0.0, colsample_bytree=0.65, score=0.682, total=   0.2s
# [CV] subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7, score=0.825, total=   0.2s
# [CV] subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7, score=0.744, total=   0.3s
# [CV] subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7, score=0.783, total=   0.3s
# [CV] subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7, score=0.690, total=   0.2s
# [CV] subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=8, max_depth=8, learning_rate=0.01, gamma=2.5, colsample_bytree=0.7, score=0.749, total=   0.2s
# [CV] subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9, score=0.808, total=   0.3s
# [CV] subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9, score=0.755, total=   0.4s
# [CV] subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9, score=0.768, total=   0.5s
# [CV] subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9, score=0.685, total=   0.6s
# [CV] subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=6, max_depth=7, learning_rate=0.01, gamma=0.0, colsample_bytree=0.9, score=0.768, total=   0.6s
# [CV] subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8, score=0.822, total=   0.5s
# [CV] subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8, score=0.757, total=   0.5s
# [CV] subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8, score=0.772, total=   0.6s
# [CV] subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8, score=0.700, total=   0.7s
# [CV] subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.5, colsample_bytree=0.8, score=0.775, total=   0.7s
# [CV] subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9, score=0.799, total=   0.3s
# [CV] subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9, score=0.711, total=   0.3s
# [CV] subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9, score=0.789, total=   0.4s
# [CV] subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9, score=0.691, total=   0.3s
# [CV] subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9
# [CV]  subsample=0.9, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=2.0, colsample_bytree=0.9, score=0.683, total=   0.3s
# [CV] subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9, score=0.816, total=   0.8s
# [CV] subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9, score=0.749, total=   0.7s
# [CV] subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9, score=0.727, total=   0.7s
# [CV] subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9, score=0.684, total=   0.7s
# [CV] subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=2, max_depth=6, learning_rate=0.1, gamma=1.5, colsample_bytree=0.9, score=0.785, total=   0.6s
# [CV] subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6
# [CV]  subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6, score=0.828, total=   0.4s
# [CV] subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6
# [CV]  subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6, score=0.757, total=   0.5s
# [CV] subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6
# [CV]  subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6, score=0.785, total=   0.4s
# [CV] subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6
# [CV]  subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6, score=0.708, total=   0.4s
# [CV] subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6
# [CV]  subsample=0.65, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=1.5, colsample_bytree=0.6, score=0.759, total=   0.5s
# [CV] subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7
# [CV]  subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7, score=0.811, total=   0.8s
# [CV] subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7
# [CV]  subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7, score=0.759, total=   0.6s
# [CV] subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7
# [CV]  subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7, score=0.722, total=   0.7s
# [CV] subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7
# [CV]  subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7, score=0.703, total=   0.6s
# [CV] subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7
# [CV]  subsample=0.6, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=1.5, colsample_bytree=0.7, score=0.767, total=   0.5s
# [CV] subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75, score=0.827, total=   0.4s
# [CV] subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75, score=0.750, total=   0.4s
# [CV] subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75, score=0.726, total=   0.5s
# [CV] subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75, score=0.690, total=   0.4s
# [CV] subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.6, min_child_weight=4, max_depth=4, learning_rate=0.1, gamma=2.5, colsample_bytree=0.75, score=0.772, total=   0.4s
# [CV] subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85
# [CV]  subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85, score=0.819, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85
# [CV]  subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85, score=0.750, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85
# [CV]  subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85, score=0.766, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85
# [CV]  subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85, score=0.698, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85
# [CV]  subsample=0.85, min_child_weight=5, max_depth=5, learning_rate=0.01, gamma=1.0, colsample_bytree=0.85, score=0.769, total=   0.5s
# [CV] subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9, score=0.806, total=   0.6s
# [CV] subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9, score=0.707, total=   0.5s
# [CV] subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9, score=0.778, total=   0.5s
# [CV] subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9, score=0.672, total=   0.6s
# [CV] subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9
# [CV]  subsample=0.55, min_child_weight=8, max_depth=5, learning_rate=0.001, gamma=0.5, colsample_bytree=0.9, score=0.707, total=   0.5s
# [CV] subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55
# [CV]  subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55, score=0.816, total=   0.5s
# [CV] subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55
# [CV]  subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55, score=0.764, total=   0.5s
# [CV] subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55
# [CV]  subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55, score=0.746, total=   0.4s
# [CV] subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55
# [CV]  subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55, score=0.698, total=   0.5s
# [CV] subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55
# [CV]  subsample=0.95, min_child_weight=6, max_depth=7, learning_rate=0.1, gamma=2.0, colsample_bytree=0.55, score=0.784, total=   0.5s
# [CV] subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6
# [CV]  subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6, score=0.821, total=   0.3s
# [CV] subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6
# [CV]  subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6, score=0.749, total=   0.3s
# [CV] subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6
# [CV]  subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6, score=0.791, total=   0.4s
# [CV] subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6
# [CV]  subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6, score=0.690, total=   0.3s
# [CV] subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6
# [CV]  subsample=0.55, min_child_weight=7, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.6, score=0.744, total=   0.3s
# [CV] subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75, score=0.820, total=   0.5s
# [CV] subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75, score=0.750, total=   0.5s
# [CV] subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75, score=0.770, total=   0.5s
# [CV] subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75, score=0.708, total=   0.5s
# [CV] subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.85, min_child_weight=4, max_depth=6, learning_rate=0.01, gamma=1.0, colsample_bytree=0.75, score=0.767, total=   0.5s
# [CV] subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5
# [CV]  subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5, score=0.806, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5
# [CV]  subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5, score=0.735, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5
# [CV]  subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5, score=0.789, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5
# [CV]  subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5, score=0.712, total=   0.5s
# [CV] subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5
# [CV]  subsample=0.8, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=0.0, colsample_bytree=0.5, score=0.708, total=   0.6s
# [CV] subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.763, total=   1.1s
# [CV] subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.722, total=   0.9s
# [CV] subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.783, total=   0.9s
# [CV] subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.696, total=   1.2s
# [CV] subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=2, max_depth=9, learning_rate=0.001, gamma=3.5, colsample_bytree=0.95, score=0.696, total=   1.3s
# [CV] subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65, score=0.829, total=   0.3s
# [CV] subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65, score=0.744, total=   0.4s
# [CV] subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65, score=0.800, total=   0.4s
# [CV] subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65, score=0.726, total=   0.6s
# [CV] subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=2, max_depth=2, learning_rate=0.01, gamma=0.0, colsample_bytree=0.65, score=0.763, total=   0.7s
# [CV] subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95
# [CV]  subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95, score=0.810, total=   1.2s
# [CV] subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95
# [CV]  subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95, score=0.767, total=   1.1s
# [CV] subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95
# [CV]  subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95, score=0.754, total=   1.4s
# [CV] subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95
# [CV]  subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95, score=0.696, total=   0.9s
# [CV] subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95
# [CV]  subsample=0.75, min_child_weight=8, max_depth=9, learning_rate=0.1, gamma=4.0, colsample_bytree=0.95, score=0.746, total=   1.2s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65, score=0.810, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65, score=0.755, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65, score=0.795, total=   0.5s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65, score=0.711, total=   0.5s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=4.5, colsample_bytree=0.65, score=0.743, total=   0.4s
# [CV] subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8, score=0.796, total=   0.4s
# [CV] subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8, score=0.723, total=   0.5s
# [CV] subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8, score=0.712, total=   0.5s
# [CV] subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8, score=0.682, total=   0.5s
# [CV] subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8
# [CV]  subsample=0.6, min_child_weight=8, max_depth=3, learning_rate=0.1, gamma=1.5, colsample_bytree=0.8, score=0.760, total=   0.5s
# [CV] subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9, score=0.820, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9, score=0.753, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9, score=0.805, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9, score=0.729, total=   0.4s
# [CV] subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9
# [CV]  subsample=0.8, min_child_weight=4, max_depth=2, learning_rate=0.01, gamma=1.5, colsample_bytree=0.9, score=0.758, total=   0.4s
# [CV] subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95, score=0.734, total=   1.2s
# [CV] subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95, score=0.714, total=   1.1s
# [CV] subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95, score=0.770, total=   1.0s
# [CV] subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95, score=0.668, total=   1.0s
# [CV] subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95
# [CV]  subsample=0.95, min_child_weight=2, max_depth=7, learning_rate=0.001, gamma=0.5, colsample_bytree=0.95, score=0.686, total=   0.9s
# [CV] subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.828, total=   0.2s
# [CV] subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.766, total=   0.2s
# [CV] subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.764, total=   0.2s
# [CV] subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.702, total=   0.2s
# [CV] subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=7, max_depth=2, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.765, total=   0.2s
# [CV] subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.799, total=   0.2s
# [CV] subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.713, total=   0.2s
# [CV] subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.776, total=   0.2s
# [CV] subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.682, total=   0.2s
# [CV] subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.6, min_child_weight=8, max_depth=2, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.699, total=   0.3s
# [CV] subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85
# [CV]  subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85, score=0.801, total=   0.3s
# [CV] subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85
# [CV]  subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85, score=0.714, total=   0.3s
# [CV] subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85
# [CV]  subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85, score=0.790, total=   0.4s
# [CV] subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85
# [CV]  subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85, score=0.693, total=   0.5s
# [CV] subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85
# [CV]  subsample=0.8, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=3.0, colsample_bytree=0.85, score=0.678, total=   0.5s
# [CV] subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65
# [CV]  subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65, score=0.808, total=   1.0s
# [CV] subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65
# [CV]  subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65, score=0.736, total=   1.1s
# [CV] subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65
# [CV]  subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65, score=0.734, total=   0.9s
# [CV] subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65
# [CV]  subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65, score=0.686, total=   1.0s
# [CV] subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65
# [CV]  subsample=0.65, min_child_weight=1, max_depth=9, learning_rate=0.1, gamma=1.0, colsample_bytree=0.65, score=0.771, total=   1.0s
# [CV] subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85
# [CV]  subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85, score=0.775, total=   0.9s
# [CV] subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85
# [CV]  subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85, score=0.722, total=   0.9s
# [CV] subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85
# [CV]  subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85, score=0.785, total=   0.9s
# [CV] subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85
# [CV]  subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85, score=0.691, total=   0.9s
# [CV] subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85
# [CV]  subsample=0.9, min_child_weight=3, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.85, score=0.691, total=   0.9s
# [CV] subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85
# [CV]  subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85, score=0.796, total=   0.8s
# [CV] subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85
# [CV]  subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85, score=0.759, total=   0.8s
# [CV] subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85
# [CV]  subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85, score=0.753, total=   0.8s
# [CV] subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85
# [CV]  subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85, score=0.689, total=   0.5s
# [CV] subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85
# [CV]  subsample=0.95, min_child_weight=3, max_depth=6, learning_rate=0.1, gamma=2.5, colsample_bytree=0.85, score=0.763, total=   0.5s
# [CV] subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9, score=0.812, total=   0.7s
# [CV] subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9, score=0.756, total=   0.6s
# [CV] subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9, score=0.694, total=   0.6s
# [CV] subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9, score=0.669, total=   0.5s
# [CV] subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.75, min_child_weight=5, max_depth=8, learning_rate=0.1, gamma=1.0, colsample_bytree=0.9, score=0.779, total=   0.5s
# [CV] subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.818, total=   0.3s
# [CV] subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.754, total=   0.4s
# [CV] subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.799, total=   0.4s
# [CV] subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.707, total=   0.4s
# [CV] subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=9, max_depth=3, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.749, total=   0.3s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7, score=0.828, total=   0.3s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7, score=0.768, total=   0.3s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7, score=0.732, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7, score=0.687, total=   0.4s
# [CV] subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7
# [CV]  subsample=0.7, min_child_weight=5, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.7, score=0.777, total=   0.4s
# [CV] subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7, score=0.804, total=   0.5s
# [CV] subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7, score=0.732, total=   0.5s
# [CV] subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7, score=0.791, total=   0.5s
# [CV] subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7, score=0.709, total=   0.5s
# [CV] subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=4, max_depth=6, learning_rate=0.001, gamma=3.0, colsample_bytree=0.7, score=0.705, total=   0.4s
# [CV] subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5
# [CV]  subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5, score=0.836, total=   0.3s
# [CV] subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5
# [CV]  subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5, score=0.740, total=   0.2s
# [CV] subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5
# [CV]  subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5, score=0.744, total=   0.2s
# [CV] subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5
# [CV]  subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5, score=0.671, total=   0.3s
# [CV] subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5
# [CV]  subsample=0.5, min_child_weight=9, max_depth=7, learning_rate=0.1, gamma=2.5, colsample_bytree=0.5, score=0.763, total=   0.3s
# [CV] subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75, score=0.806, total=   0.3s
# [CV] subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75, score=0.744, total=   0.4s
# [CV] subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75, score=0.796, total=   0.3s
# [CV] subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75, score=0.716, total=   0.4s
# [CV] subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=6, max_depth=3, learning_rate=0.01, gamma=4.0, colsample_bytree=0.75, score=0.739, total=   0.3s
# [CV] subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.837, total=   0.5s
# [CV] subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.751, total=   0.5s
# [CV] subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.742, total=   0.6s
# [CV] subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.679, total=   0.6s
# [CV] subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8
# [CV]  subsample=0.5, min_child_weight=4, max_depth=7, learning_rate=0.1, gamma=3.5, colsample_bytree=0.8, score=0.778, total=   0.6s
# [CV] subsample=0.75, min_child_weight=5, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.75, min_child_weight=5, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.75, score=0.805, total=   0.4s
# [CV] subsample=0.75, min_child_weight=5, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.75
# [CV]  subsample=0.75, min_child_weight=5, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.75, score=0.718, total=   0.3s
# ...
# [CV] subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7, score=0.828, total=   0.4s
# [CV] subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7, score=0.736, total=   0.5s
# [CV] subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7, score=0.754, total=   0.5s
# [CV] subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7, score=0.686, total=   0.5s
# [CV] subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7
# [CV]  subsample=0.55, min_child_weight=7, max_depth=6, learning_rate=0.1, gamma=3.5, colsample_bytree=0.7, score=0.774, total=   0.5s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75, score=0.774, total=   0.7s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75, score=0.725, total=   0.8s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75, score=0.783, total=   0.7s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75, score=0.697, total=   0.6s
# [CV] subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75
# [CV]  subsample=0.95, min_child_weight=5, max_depth=8, learning_rate=0.001, gamma=2.5, colsample_bytree=0.75, score=0.696, total=   0.7s
# [CV] subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.812, total=   0.6s
# [CV] subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.733, total=   0.5s
# [CV] subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.792, total=   0.7s
# [CV] subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.716, total=   0.7s
# [CV] subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=1, max_depth=7, learning_rate=0.001, gamma=4.0, colsample_bytree=0.65, score=0.717, total=   0.8s
# [CV] subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5
# [CV]  subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5, score=0.811, total=   0.4s
# [CV] subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5
# [CV]  subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5, score=0.726, total=   0.3s
# [CV] subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5
# [CV]  subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5, score=0.793, total=   0.3s
# [CV] subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5
# [CV]  subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5, score=0.720, total=   0.4s
# [CV] subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5
# [CV]  subsample=0.6, min_child_weight=3, max_depth=3, learning_rate=0.001, gamma=1.0, colsample_bytree=0.5, score=0.699, total=   0.4s
# [CV] subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6
# [CV]  subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6, score=0.781, total=   0.7s
# [CV] subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6
# [CV]  subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6, score=0.725, total=   0.6s
# [CV] subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6
# [CV]  subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6, score=0.786, total=   0.5s
# [CV] subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6
# [CV]  subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6, score=0.706, total=   0.6s
# [CV] subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6
# [CV]  subsample=0.95, min_child_weight=2, max_depth=8, learning_rate=0.001, gamma=3.0, colsample_bytree=0.6, score=0.705, total=   0.5s
# [CV] subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.812, total=   0.4s
# [CV] subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.737, total=   0.4s
# [CV] subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.703, total=   0.4s
# [CV] subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.670, total=   0.4s
# [CV] subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.5, min_child_weight=2, max_depth=8, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.754, total=   0.4s
# [CV] subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9, score=0.774, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9, score=0.732, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9, score=0.779, total=   0.6s
# [CV] subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9, score=0.687, total=   0.5s
# [CV] subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9
# [CV]  subsample=0.85, min_child_weight=5, max_depth=6, learning_rate=0.001, gamma=1.0, colsample_bytree=0.9, score=0.698, total=   0.5s
# [CV] subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55
# [CV]  subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55, score=0.818, total=   0.3s
# [CV] subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55
# [CV]  subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55, score=0.755, total=   0.3s
# [CV] subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55
# [CV]  subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55, score=0.789, total=   0.3s
# [CV] subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55
# [CV]  subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55, score=0.707, total=   0.3s
# [CV] subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55
# [CV]  subsample=0.55, min_child_weight=4, max_depth=4, learning_rate=0.01, gamma=3.0, colsample_bytree=0.55, score=0.755, total=   0.3s
# [CV] subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.814, total=   0.4s
# [CV] subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.751, total=   0.4s
# [CV] subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.780, total=   0.4s
# [CV] subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.716, total=   0.4s
# [CV] subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95
# [CV]  subsample=0.9, min_child_weight=5, max_depth=4, learning_rate=0.01, gamma=2.5, colsample_bytree=0.95, score=0.765, total=   0.4s
# [CV] subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8
# [CV]  subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8, score=0.807, total=   0.4s
# [CV] subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8
# [CV]  subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8, score=0.760, total=   0.4s
# [CV] subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8
# [CV]  subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8, score=0.716, total=   0.4s
# [CV] subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8
# [CV]  subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8, score=0.679, total=   0.4s
# [CV] subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8
# [CV]  subsample=0.65, min_child_weight=6, max_depth=4, learning_rate=0.1, gamma=2.0, colsample_bytree=0.8, score=0.783, total=   0.4s
# [CV] subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8, score=0.799, total=   0.4s
# [CV] subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8, score=0.725, total=   0.4s
# [CV] subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8, score=0.788, total=   0.4s
# [CV] subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8, score=0.703, total=   0.5s
# [CV] subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8
# [CV]  subsample=0.75, min_child_weight=4, max_depth=5, learning_rate=0.001, gamma=4.0, colsample_bytree=0.8, score=0.695, total=   0.4s
# [CV] subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.817, total=   0.2s
# [CV] subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.742, total=   0.2s
# [CV] subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.719, total=   0.2s
# [CV] subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.679, total=   0.2s
# [CV] subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65
# [CV]  subsample=0.85, min_child_weight=2, max_depth=3, learning_rate=0.1, gamma=0.5, colsample_bytree=0.65, score=0.770, total=   0.2s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95, score=0.814, total=   0.5s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95, score=0.761, total=   0.5s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95, score=0.714, total=   0.5s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95, score=0.670, total=   0.5s
# [CV] subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95
# [CV]  subsample=0.8, min_child_weight=5, max_depth=5, learning_rate=0.1, gamma=2.0, colsample_bytree=0.95, score=0.774, total=   0.5s
# [Parallel(n_jobs=1)]: Done 5000 out of 5000 | elapsed: 36.3min finished
#  Time taken: 0 hours 36 minutes and 17.92 seconds.

# %%
print(random_search.best_estimator_)
best_xgb = random_search.best_estimator_
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.75, gamma=1.5, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.01, max_delta_step=0, max_depth=2,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=600, n_jobs=4, nthread=4, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, silent=True, subsample=0.6,
#               tree_method=None, validate_parameters=False, verbosity=None)

# %% [markdown]
# ### 5. Ewaluacja modeli

# %%
def evaluateModel(model, X_train, Y_train, X_test, Y_test):
    model.fit(X_train, Y_train)
    y_pred = model.predict(X_test)
    y_proba = model.predict_proba(X_test)[:, 1]
    y_true = Y_test
    print("Accuracy: " + str(accuracy_score(y_true, y_pred, normalize=False)))
    print("Precision: " + str(precision_score(y_true, y_pred, average='macro')))
    print("Recall: " + str(recall_score(y_true, y_pred)))
    fpr, tpr, thresholds = metrics.roc_curve(y_true, y_proba, pos_label=2)
    print("AUC: " + str(metrics.auc(fpr, tpr)))
    plt.figure()
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr)
    plt.xlabel('False positive rate')
    plt.ylabel('True positive rate')
    plt.title('ROC curve')
    plt.show()

# %%
evaluateModel(best_xgb, ohe_train, Y_train,
              ohe_test, Y_test)
# Out:
# Accuracy: 187
# Precision: 0.7228713724739009
# Recall: 0.8988095238095238
# AUC: 0.8087253193960512

# %%
evaluateModel(xgb_classifier, ohe_train, Y_train,
              ohe_test, Y_test)
# Out:
# Accuracy: 196
# Precision: 0.7691271551724138
# Recall: 0.9107142857142857
# AUC: 0.8172909407665505

# %%
xgb_classifier
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.02, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=600, n_jobs=4, nthread=4, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, silent=True, subsample=1,
#               tree_method=None, validate_parameters=False, verbosity=None)

# %%
best_xgb
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.75, gamma=1.5, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.01, max_delta_step=0, max_depth=2,
#               min_child_weight=3, missing=nan, monotone_constraints=None,
#               n_estimators=600, n_jobs=4, nthread=4, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, silent=True, subsample=0.6,
#               tree_method=None, validate_parameters=False, verbosity=None)
